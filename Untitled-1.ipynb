# %%
import pandas as pd
import json

file_schema_path = './data/processed/file_schema.json'

# %%
with open(file_schema_path, 'r') as f:
        file_schema = json.load(f)

# %%
df = pd.DataFrame()
for base_name in file_schema.keys():

    # get metadata
    data = pd.read_table(file_schema[base_name]["src_path_tsv"], sep = "\t", index_col=False)

    grouping_cols = [col for col in data.columns if "Speaker" in col] + ["Party_status", "Party_orientation"]
    speaker_count = data.groupby(grouping_cols, as_index=False).size()
    df_out = speaker_count
    # add metadata
    df_out["Debate_ID"] = base_name
    df_out["Date"] = f'{file_schema[base_name]["year"]}-{file_schema[base_name]["month"]}-{file_schema[base_name]["day"]}'
    df_out["House"] = file_schema[base_name]["chamber"]
    df_out["Debate_Num"] = file_schema[base_name]["debate_num"]
    df_out = df_out[["Date", "Debate_Num", "House", "Debate_ID"] + grouping_cols + ["size"]]
    df_out = df_out.drop(columns=["Speaker_birth", "Speaker_gender"])

    # append to main dataframe
    df = pd.concat([df, df_out])
    
df.to_csv('./data/processed/speaker_count.csv', index=False)
print("Speaker count data saved to ./data/processed/speaker_count.csv")
# Out:
# Speaker count data saved to ./data/processed/speaker_count.csv

# %%
df
# Out:
#           Date Debate_Num        House                  Debate_ID  \
# 0   2022-01-18          8  eerstekamer   2022-01-18-eerstekamer-8
# 1   2022-01-18          8  eerstekamer   2022-01-18-eerstekamer-8
# 2   2022-01-18          8  eerstekamer   2022-01-18-eerstekamer-8
# 3   2022-01-18          8  eerstekamer   2022-01-18-eerstekamer-8
# 4   2022-01-18          8  eerstekamer   2022-01-18-eerstekamer-8
# ..         ...        ...          ...                        ...
# 11  2022-07-12         32  eerstekamer  2022-07-12-eerstekamer-32
# 12  2022-07-12         32  eerstekamer  2022-07-12-eerstekamer-32
# 13  2022-07-12         32  eerstekamer  2022-07-12-eerstekamer-32
# 14  2022-07-12         32  eerstekamer  2022-07-12-eerstekamer-32
# 15  2022-07-12         32  eerstekamer  2022-07-12-eerstekamer-32
#
#    Speaker_role Speaker_MP Speaker_minister Speaker_party  \
# 0   Chairperson         MP      notMinister           VVD
# 1         Guest         MP      notMinister           FvD
# 2         Guest      notMP      notMinister           CDA
# 3         Guest      notMP      notMinister           D66
# 4         Guest      notMP      notMinister           D66
# ..          ...        ...              ...           ...
# 11        Guest      notMP      notMinister            GL
# 12        Guest      notMP      notMinister          PvdD
# 13        Guest      notMP      notMinister           SGP
# 14        Guest      notMP      notMinister            SP
# 15        Guest      notMP      notMinister           VVD
#
#                          Speaker_party_name         Speaker_ID  \
# 0   Volkspartij voor Vrijheid en Democratie  JanAnthonieBruijn
# 1                     Forum voor Democratie       PaulFrentrop
# 2               Christen-Democratisch Appèl          JoopAtsma
# 3                             Democraten 66          GunayUslu
# 4                             Democraten 66        HenkPijlman
# ..                                      ...                ...
# 11                               GroenLinks        RoelvanGurp
# 12                    Partij voor de Dieren       NikoKoffeman
# 13         Staatkundig Gereformeerde Partij        PeterSchalk
# 14                    Socialistische Partij            TinyKox
# 15  Volkspartij voor Vrijheid en Democratie    PaulienGeerdink
#
#             Speaker_name Party_status       Party_orientation  size
# 0   Bruijn, Jan Anthonie    Coalition            Centre-right    89
# 1         Frentrop, Paul   Opposition               Far-right     9
# 2            Atsma, Joop    Coalition  Centre to centre-right    13
# 3            Uslu, Gunay    Coalition                  Centre    50
# 4          Pijlman, Henk    Coalition                  Centre     8
# ..                   ...          ...                     ...   ...
# 11        van Gurp, Roel   Opposition     Centre-left to left     5
# 12        Koffeman, Niko   Opposition                    Left     8
# 13         Schalk, Peter   Opposition                   Right    14
# 14             Kox, Tiny   Opposition                    Left    16
# 15     Geerdink, Paulien    Coalition            Centre-right     5
#
# [3465 rows x 14 columns]
